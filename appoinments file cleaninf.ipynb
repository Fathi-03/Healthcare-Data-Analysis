# %%
#load libraries 
import numpy as np 
import pandas as pd

# %%
# load data into data frame
df = pd.read_csv(r"E:\Dat for BigProject\Hospital 🏥\CSVs\Appointment.csv")

# %%
# display first 5 rows
df.head()
# Out:
#   appointment_id patient_id doctor_id appointment_date appointment_time  \
# 0         APP001       P001      D001       2023-05-14         10:00:00
# 1         APP002       P002      D004       2023-05-17         11:30:00
# 2         APP003       P003      D007       2023-05-19         14:00:00
# 3         APP004       P004      D006       2023-06-01         09:30:00
# 4         APP005       P005      D003       2023-06-04         13:00:00
#
#       status           reason                             notes  \
# 0  Completed       Chest Pain  Patient complained of chest pain
# 1  Completed  Regular Checkup     Regular gynecological checkup
# 2  Completed     Stomach Pain     Patient has chronic gastritis
# 3  Completed        Skin Rash                 Allergic reaction
# 4  Completed        Back Pain                     Lumbar strain
#
#                       suggest fees payment_method  discount  \
# 0       prescribed medication  800           Cash       0.0
# ...

# %%
# get shape of dataframe
df.shape
# Out:
# (35, 13)

# %%
# Get som info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   appointment_id    35 non-null     object
#  1   patient_id        35 non-null     object
#  2   doctor_id         35 non-null     object
#  3   appointment_date  35 non-null     object
#  4   appointment_time  35 non-null     object
#  5   status            35 non-null     object
#  6   reason            35 non-null     object
#  7   notes             35 non-null     object
#  8   suggest           35 non-null     object
#  9   fees              35 non-null     object
#  10  payment_method    35 non-null     object
#  11  discount          30 non-null     float64
#  12  diagnosis         35 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 3.7+ KB

# %%
# Sample to show type of column
df.sample(1)
# Out:
#   appointment_id patient_id doctor_id appointment_date appointment_time  \
# 6         APP007       P007      D002       2023-06-14         10:00:00
#
#       status           reason              notes                suggest fees  \
# 6  Completed  Severe Headache  Possible migraine   further tests needed  850
#
#   payment_method  discount diagnosis
# 6      Insurance       0.0    Stroke

# %%
# display all dataframe
df
# Out:
#    appointment_id patient_id doctor_id appointment_date appointment_time  \
# 0          APP001       P001      D001       2023-05-14         10:00:00
# 1          APP002       P002      D004       2023-05-17         11:30:00
# 2          APP003       P003      D007       2023-05-19         14:00:00
# 3          APP004       P004      D006       2023-06-01         09:30:00
# 4          APP005       P005      D003       2023-06-04         13:00:00
# 5          APP006       P006      D009       2023-06-09         16:30:00
# 6          APP007       P007      D002       2023-06-14         10:00:00
# 7          APP008       P008      D010       2023-06-17         11:30:00
# 8          APP009       P009      D011       2023-06-19         14:00:00
# 9          APP010       P010      D005       2023-06-30         09:30:00
# 10         APP011       P011      D013       2023-07-04         13:00:00
# 11         APP012       P012      D006       2023-07-09         16:30:00
# ...

# %%
# show columns name
df.columns
# Out:
# Index(['appointment_id', 'patient_id', 'doctor_id', 'appointment_date',
#        'appointment_time', 'status', 'reason', 'notes', 'suggest', 'fees',
#        'payment_method', 'discount', 'diagnosis'],
#       dtype='object')

# %%
# make temp column for fees column
temp_fees = df['fees'].copy()

# %%
# replace values between fees and suggest column
df.loc[30:,'fees'] = df.loc[30:,'suggest']
df.loc[30:,'suggest'] = temp_fees.loc[30:]

# %%
# check data type for columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   appointment_id    35 non-null     object
#  1   patient_id        35 non-null     object
#  2   doctor_id         35 non-null     object
#  3   appointment_date  35 non-null     object
#  4   appointment_time  35 non-null     object
#  5   status            35 non-null     object
#  6   reason            35 non-null     object
#  7   notes             35 non-null     object
#  8   suggest           35 non-null     object
#  9   fees              35 non-null     object
#  10  payment_method    35 non-null     object
#  11  discount          30 non-null     float64
#  12  diagnosis         35 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 3.7+ KB

# %%
# replace null values in column discount with mode value
df['discount']=df['discount'].fillna(df['discount'].mode()[0])

# %%
# replace null values in column payment_mathod with mode value
df['payment_method']=df['payment_method'].replace('0',df['payment_method'].mode()[0])

# %%
# check replce result
df['payment_method']
# Out:
# 0            Cash
# 1     Credit Card
# 2       Insurance
# 3            Cash
# 4       Insurance
# 5     Credit Card
# 6       Insurance
# 7            Cash
# 8     Credit Card
# 9       Insurance
# 10           Cash
# 11    Credit Card
# 12      Insurance
# 13           Cash
# 14      Insurance
# 15    Credit Card
# 16           Cash
# 17      Insurance
# 18    Credit Card
# 19           Cash
# 20      Insurance
# 21    Credit Card
# 22           Cash
# 23      Insurance
# 24    Credit Card
# 25           Cash
# 26      Insurance
# 27    Credit Card
# 28           Cash
# 29      Insurance
# 30      Insurance
# 31      Insurance
# 32      Insurance
# 33      Insurance
# 34      Insurance
# Name: payment_method, dtype: object

# %%
# check type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   appointment_id    35 non-null     object
#  1   patient_id        35 non-null     object
#  2   doctor_id         35 non-null     object
#  3   appointment_date  35 non-null     object
#  4   appointment_time  35 non-null     object
#  5   status            35 non-null     object
#  6   reason            35 non-null     object
#  7   notes             35 non-null     object
#  8   suggest           35 non-null     object
#  9   fees              35 non-null     object
#  10  payment_method    35 non-null     object
#  11  discount          35 non-null     float64
#  12  diagnosis         35 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 3.7+ KB

# %%
# check for null
df.isnull().sum()
# Out:
# appointment_id      0
# patient_id          0
# doctor_id           0
# appointment_date    0
# appointment_time    0
# status              0
# reason              0
# notes               0
# suggest             0
# fees                0
# payment_method      0
# discount            0
# diagnosis           0
# dtype: int64

# %%
# see data
df
# Out:
#    appointment_id patient_id doctor_id appointment_date appointment_time  \
# 0          APP001       P001      D001       2023-05-14         10:00:00
# 1          APP002       P002      D004       2023-05-17         11:30:00
# 2          APP003       P003      D007       2023-05-19         14:00:00
# 3          APP004       P004      D006       2023-06-01         09:30:00
# 4          APP005       P005      D003       2023-06-04         13:00:00
# 5          APP006       P006      D009       2023-06-09         16:30:00
# 6          APP007       P007      D002       2023-06-14         10:00:00
# 7          APP008       P008      D010       2023-06-17         11:30:00
# 8          APP009       P009      D011       2023-06-19         14:00:00
# 9          APP010       P010      D005       2023-06-30         09:30:00
# 10         APP011       P011      D013       2023-07-04         13:00:00
# 11         APP012       P012      D006       2023-07-09         16:30:00
# ...

# %%
# check duplicated in columnn appointment_id
df['appointment_id'].drop_duplicates().shape[0]
# Out:
# 35

# %%
# save cleaning data
df.to_csv('clean_appointment.CSV',index=False)
